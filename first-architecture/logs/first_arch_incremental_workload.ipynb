# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

logs_first_arch_java_1_invoker_incremental1 = "logs_first_arch_java_1_invoker_incremental110.txt"
logs_first_arch_java_2_invoker_incremental1 = "logs_first_arch_java_2_invoker_incremental110.txt"
logs_first_arch_java_4_invoker_incremental1 = "logs_first_arch_java_4_invoker_incremental110.txt"

logs_first_arch_java_4_invoker_incremental2 = "logs_first_arch_java_4_invoker_incremental111.txt"



acl_java1 = pd.read_csv (logs_first_arch_java_1_invoker_incremental1, names = ["timestamp", "level", "message"])
acl_java2 = pd.read_csv (logs_first_arch_java_2_invoker_incremental1, names = ["timestamp", "level", "message"])
acl_java4 = pd.read_csv (logs_first_arch_java_4_invoker_incremental1, names = ["timestamp", "level", "message"])

acl_java42 = pd.read_csv (logs_first_arch_java_4_invoker_incremental2, names = ["timestamp", "level", "message"])


acl_java4 = pd.concat([acl_java4, acl_java42])
acl_java4 = acl_java4.sort_values(by=['timestamp'])



#acl java 1 invoker incremental first arch
list1 = []
list1 = acl_java1["message"].tolist()
listMDB = []
for x in list1:
    if x.count("Read")>0:
        listMDB.append(x.split(" "))
listMDB2 = []
for x in listMDB:
    listMDB2.append(int(x[-2]))
acl_java_mdb1 = np.array(listMDB2)

list1 = []
list1 = acl_java1["message"].tolist()
list2 = []
for x in list1:
    if x.count("example")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    match = re.match(r"([\d.]+)([a-zA-Z]+)", x[-1])
    if match.group(2) == "s":
        list3.append(float(match.group(1))*1000)
    else:
        list3.append(float(match.group(1)))
acl_java_tot1 = np.array(list3)

list1 = []
list1 = acl_java1["message"].tolist()
list2 = []
for x in list1:
    if x.count("access")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[-2]))
acl_java_fun1 = np.array(list3)



#acl java 2 invoker incremental first arch
list1 = []
list1 = acl_java2["message"].tolist()
listMDB = []
for x in list1:
    if x.count("Read")>0:
        listMDB.append(x.split(" "))
listMDB2 = []
for x in listMDB:
    listMDB2.append(int(x[-2]))
acl_java_mdb2 = np.array(listMDB2)

list1 = []
list1 = acl_java2["message"].tolist()
list2 = []
for x in list1:
    if x.count("example")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    match = re.match(r"([\d.]+)([a-zA-Z]+)", x[-1])
    if match.group(2) == "s":
        list3.append(float(match.group(1))*1000)
    else:
        list3.append(float(match.group(1)))
acl_java_tot2 = np.array(list3)

list1 = []
list1 = acl_java2["message"].tolist()
list2 = []
for x in list1:
    if x.count("access")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[-2]))
acl_java_fun2 = np.array(list3)




#acl java 4 invoker incremental first arch
list1 = []
list1 = acl_java4["message"].tolist()
listMDB = []
for x in list1:
    if x.count("Read")>0:
        listMDB.append(x.split(" "))
listMDB2 = []
for x in listMDB:
    listMDB2.append(int(x[-2]))
acl_java_mdb4 = np.array(listMDB2)

list1 = []
list1 = acl_java4["message"].tolist()
list2 = []
for x in list1:
    if x.count("example")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    match = re.match(r"([\d.]+)([a-zA-Z]+)", x[-1])
    if match.group(2) == "s":
        list3.append(float(match.group(1))*1000)
    else:
        list3.append(float(match.group(1)))
acl_java_tot4 = np.array(list3)

list1 = []
list1 = acl_java4["message"].tolist()
list2 = []
for x in list1:
    if x.count("access")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[-2]))
acl_java_fun4 = np.array(list3)



acl_java_tot1_rps = []
acl_java_mdb1_rps = []
acl_java_fun1_rps = []
used = 0
for x in range (1, 21, 1):
    y = np.mean(acl_java_tot1[used:used+x])
    acl_java_tot1_rps.append(y)
    y = np.mean(acl_java_mdb1[used:used+x])
    acl_java_mdb1_rps.append(y)
    y = np.mean(acl_java_fun1[used:used+x])
    acl_java_fun1_rps.append(y)
    used = used+x


acl_java_tot2_rps = []
acl_java_mdb2_rps = []
acl_java_fun2_rps = []
used = 0
for x in range (1, 21, 1):
    y = np.mean(acl_java_tot2[used:used+x])
    acl_java_tot2_rps.append(y)
    y = np.mean(acl_java_mdb2[used:used+x])
    acl_java_mdb2_rps.append(y)
    y = np.mean(acl_java_fun2[used:used+x])
    acl_java_fun2_rps.append(y)
    used = used+x


acl_java_tot4_rps = []
acl_java_mdb4_rps = []
acl_java_fun4_rps = []
used = 0
for x in range (1, 21, 1):
    y = np.mean(acl_java_tot4[used:used+x])
    acl_java_tot4_rps.append(y)
    y = np.mean(acl_java_mdb4[used:used+x])
    acl_java_mdb4_rps.append(y)
    y = np.mean(acl_java_fun4[used:used+x])
    acl_java_fun4_rps.append(y)
    used = used+x


rps_java = range(1, 21, 1)
# Out:
# C:\Users\Fabio Gentili\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\Fabio Gentili\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
#acl java tot incremental first arch
fig, ax = plt.subplots(figsize = (20,8)) 
ax.set_title("Different configurations with incremental workload (Java function)", fontsize = 40)
ax.set_xlabel('Requests / sec', fontsize = 26)
ax.set_ylabel('Mean end-to-end latency [ms]', fontsize = 26)
ax.plot(rps_java, acl_java_tot1_rps, label = '1x invoker')
ax.plot(rps_java, acl_java_tot2_rps, label = '2x invoker')
ax.plot(rps_java, acl_java_tot4_rps, label = '4x invoker')
#ax.plot(log_go_tot, label = 'log function')
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
ax.grid(True, linewidth=0.5)
ax.set_xticks(range(0,21,5))
#plt.yscale('log')
plt.legend(loc = 'upper left')
plt.rc('legend', fontsize = 25)
plt.show()

# %%
#acl java mdb incremental first arch
fig, ax = plt.subplots(figsize = (20,8)) 
ax.set_title("Different configurations with incremental workload (Java function)", fontsize = 40)
ax.set_xlabel('Requests / sec', fontsize = 26)
ax.set_ylabel('Mean service binding time [ms]', fontsize = 26)
ax.plot(rps_java, acl_java_mdb1_rps, label = '1x invoker')
ax.plot(rps_java, acl_java_mdb2_rps, label = '2x invoker')
ax.plot(rps_java, acl_java_mdb4_rps, label = '4x invoker')
#ax.plot(log_go_tot, label = 'log function')
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
ax.grid(True, linewidth=0.5)
ax.set_xticks(range(0,21,5))
#plt.yscale('log')
plt.legend(loc = 'upper right')
plt.rc('legend', fontsize = 25)
plt.show()

# %%
#acl java fun incremental first arch
fig, ax = plt.subplots(figsize = (20,8)) 
ax.set_title("Different configurations with incremental workload (Java function)", fontsize = 40)
ax.set_xlabel('Requests / sec', fontsize = 26)
ax.set_ylabel('Mean service invocation time [ms]', fontsize = 26)
ax.plot(rps_java, acl_java_fun1_rps, label = '1x invoker')
ax.plot(rps_java, acl_java_fun2_rps, label = '2x invoker')
ax.plot(rps_java, acl_java_fun4_rps, label = '4x invoker')
#ax.plot(log_go_tot, label = 'log function')
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
ax.grid(True, linewidth=0.5)
ax.set_xticks(range(0,21,5))
#plt.yscale('log')
plt.legend(loc = 'upper right')
plt.rc('legend', fontsize = 25)
plt.show()

# %%
logs_first_arch_js_1_invoker_incremental1 = "logs_first_arch_js_1_invoker_incremental110.txt"
logs_first_arch_js_2_invoker_incremental1 = "logs_first_arch_js_2_invoker_incremental110.txt"
logs_first_arch_js_4_invoker_incremental1 = "logs_first_arch_js_4_invoker_incremental110.txt"

logs_first_arch_js_4_invoker_incremental2 = "logs_first_arch_js_4_invoker_incremental111.txt"


acl_js1 = pd.read_csv (logs_first_arch_js_1_invoker_incremental1, names = ["timestamp", "level", "message"])
acl_js2 = pd.read_csv (logs_first_arch_js_2_invoker_incremental1, names = ["timestamp", "level", "message"])
acl_js4 = pd.read_csv (logs_first_arch_js_4_invoker_incremental1, names = ["timestamp", "level", "message"])

acl_js42 = pd.read_csv (logs_first_arch_js_4_invoker_incremental2, names = ["timestamp", "level", "message"])

acl_js4 = pd.concat([acl_js4, acl_js42])
acl_js4 = acl_js4.sort_values(by=['timestamp'])



#acl js 1 invoker incremental first arch
list1 = []
list1 = acl_js1["message"].tolist()
listMDB = []
for x in list1:
    if x.count("Read")>0:
        listMDB.append(x.split(" "))
listMDB2 = []
for x in listMDB:
    listMDB2.append(int(x[-3]))
acl_js_mdb1 = np.array(listMDB2)

list1 = []
list1 = acl_js1["message"].tolist()
list2 = []
for x in list1:
    if x.count("example")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    match = re.match(r"([\d.]+)([a-zA-Z]+)", x[-1])
    if match.group(2) == "s":
        list3.append(float(match.group(1))*1000)
    else:
        list3.append(float(match.group(1)))
acl_js_tot1 = np.array(list3)

list1 = []
list1 = acl_js1["message"].tolist()
list2 = []
for x in list1:
    if x.count("access")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[-3]))
acl_js_fun1 = np.array(list3)



#acl js 2 invoker incremental first arch
list1 = []
list1 = acl_js2["message"].tolist()
listMDB = []
for x in list1:
    if x.count("Read")>0:
        listMDB.append(x.split(" "))
listMDB2 = []
for x in listMDB:
    listMDB2.append(int(x[-3]))
acl_js_mdb2 = np.array(listMDB2)

list1 = []
list1 = acl_js2["message"].tolist()
list2 = []
for x in list1:
    if x.count("example")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    match = re.match(r"([\d.]+)([a-zA-Z]+)", x[-1])
    if match.group(2) == "s":
        list3.append(float(match.group(1))*1000)
    else:
        list3.append(float(match.group(1)))
acl_js_tot2 = np.array(list3)

list1 = []
list1 = acl_js2["message"].tolist()
list2 = []
for x in list1:
    if x.count("access")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[-3]))
acl_js_fun2 = np.array(list3)




#acl js 4 invoker incremental first arch
list1 = []
list1 = acl_js4["message"].tolist()
listMDB = []
for x in list1:
    if x.count("Read")>0:
        listMDB.append(x.split(" "))
listMDB2 = []
for x in listMDB:
    listMDB2.append(int(x[-3]))
acl_js_mdb4 = np.array(listMDB2)

list1 = []
list1 = acl_js4["message"].tolist()
list2 = []
for x in list1:
    if x.count("example")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    match = re.match(r"([\d.]+)([a-zA-Z]+)", x[-1])
    if match.group(2) == "s":
        list3.append(float(match.group(1))*1000)
    else:
        list3.append(float(match.group(1)))
acl_js_tot4 = np.array(list3)

list1 = []
list1 = acl_js4["message"].tolist()
list2 = []
for x in list1:
    if x.count("access")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[-3]))
acl_js_fun4 = np.array(list3)




acl_js_tot1_rps = []
acl_js_mdb1_rps = []
acl_js_fun1_rps = []
used = 0
for x in range (1, 51, 1):
    y = np.mean(acl_js_tot1[used:used+x])
    acl_js_tot1_rps.append(y)
    y = np.mean(acl_js_mdb1[used:used+x])
    acl_js_mdb1_rps.append(y)
    y = np.mean(acl_js_fun1[used:used+x])
    acl_js_fun1_rps.append(y)
    used = used+x


acl_js_tot2_rps = []
acl_js_mdb2_rps = []
acl_js_fun2_rps = []
used = 0
for x in range (1, 51, 1):
    y = np.mean(acl_js_tot2[used:used+x])
    acl_js_tot2_rps.append(y)
    y = np.mean(acl_js_mdb2[used:used+x])
    acl_js_mdb2_rps.append(y)
    y = np.mean(acl_js_fun2[used:used+x])
    acl_js_fun2_rps.append(y)
    used = used+x


acl_js_tot4_rps = []
acl_js_mdb4_rps = []
acl_js_fun4_rps = []
used = 0
for x in range (1, 51, 1):
    y = np.mean(acl_js_tot4[used:used+x])
    acl_js_tot4_rps.append(y)
    y = np.mean(acl_js_mdb4[used:used+x])
    acl_js_mdb4_rps.append(y)
    y = np.mean(acl_js_fun4[used:used+x])
    acl_js_fun4_rps.append(y)
    used = used+x


rps_js = range(1, 51, 1)
# Out:
# C:\Users\Fabio Gentili\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\Fabio Gentili\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
#acl js tot incremental first arch
fig, ax = plt.subplots(figsize = (20,8)) 
ax.set_title("Different configurations with incremental workload (Javascript function)", fontsize = 40)
ax.set_xlabel('Requests / sec', fontsize = 26)
ax.set_ylabel('Mean end-to-end latency [ms]', fontsize = 26)
ax.plot(rps_js, acl_js_tot1_rps, label = '1x invoker')
ax.plot(rps_js, acl_js_tot2_rps, label = '2x invoker')
ax.plot(rps_js, acl_js_tot4_rps, label = '4x invoker')
#ax.plot(log_go_tot, label = 'log function')
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
ax.grid(True, linewidth=0.5)
ax.set_xticks(range(5,51,5))
#plt.yscale('log')
plt.legend(loc = 'upper left')
plt.rc('legend', fontsize = 25)
plt.show()

# %%
#acl js mdb incremental first arch
fig, ax = plt.subplots(figsize = (20,8)) 
ax.set_title("Different configurations with incremental workload (Javascript function)", fontsize = 40)
ax.set_xlabel('Requests / sec', fontsize = 26)
ax.set_ylabel('Mean service binding time [ms]', fontsize = 26)
ax.plot(rps_js, acl_js_mdb1_rps, label = '1x invoker')
ax.plot(rps_js, acl_js_mdb2_rps, label = '2x invoker')
ax.plot(rps_js, acl_js_mdb4_rps, label = '4x invoker')
#ax.plot(log_go_tot, label = 'log function')
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
ax.grid(True, linewidth=0.5)
ax.set_xticks(range(5,51,5))
#plt.yscale('log')
plt.legend(loc = 'upper left')
plt.rc('legend', fontsize = 25)
plt.show()

# %%
#acl js fun incremental first arch
fig, ax = plt.subplots(figsize = (20,8)) 
ax.set_title("Different configurations with incremental workload (Javascript function)", fontsize = 40)
ax.set_xlabel('Requests / sec', fontsize = 26)
ax.set_ylabel('Mean service invocation time [ms]', fontsize = 26)
ax.plot(rps_js, acl_js_fun1_rps, label = '1x invoker')
ax.plot(rps_js, acl_js_fun2_rps, label = '2x invoker')
ax.plot(rps_js, acl_js_fun4_rps, label = '4x invoker')
#ax.plot(log_go_tot, label = 'log function')
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
ax.grid(True, linewidth=0.5)
ax.set_xticks(range(5,51,5))
#plt.yscale('log')
plt.legend(loc = 'upper left')
plt.rc('legend', fontsize = 25)
plt.show()

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt


logs_first_arch_go_1_invoker_incremental1 = "logs_first_arch_go_1_invoker_incremental100.txt"
logs_first_arch_go_2_invoker_incremental1 = "logs_first_arch_go_2_invoker_incremental100.txt"
logs_first_arch_go_4_invoker_incremental1 = "logs_first_arch_go_4_invoker_incremental100.txt"
logs_first_arch_go_4_invoker_incremental2 = "logs_first_arch_go_4_invoker_incremental101.txt"


acl_go1 = pd.read_csv (logs_first_arch_go_1_invoker_incremental1, names = ["timestamp", "level", "message"])
acl_go2 = pd.read_csv (logs_first_arch_go_2_invoker_incremental1, names = ["timestamp", "level", "message"])
acl_go4 = pd.read_csv (logs_first_arch_go_4_invoker_incremental1, names = ["timestamp", "level", "message"])
acl_go42 = pd.read_csv (logs_first_arch_go_4_invoker_incremental2, names = ["timestamp", "level", "message"])

acl_go4 = pd.concat([acl_go4, acl_go42])
acl_go4 = acl_go4.sort_values(by=['timestamp'])



#acl go 1 invoker incremental first arch
list1 = []
list1 = acl_go1["message"].tolist()
listMDB = []
for x in list1:
    if x.count("Read")>0:
        listMDB.append(x.split(" "))
listMDB2 = []
for x in listMDB:
    listMDB2.append(int(x[-2]))
acl_go_mdb1 = np.array(listMDB2)


list1 = []
list1 = acl_go1["message"].tolist()
list2 = []
for x in list1:
    if x.count("example")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    match = re.match(r"([\d.]+)([µa-zA-Z]+)", x[-1])
    if match.group(2) == "s":
        list3.append(float(match.group(1))*1000)
    elif match.group(2) == "µs":
        list3.append(float(match.group(1))/1000)
    else:
        list3.append(float(match.group(1)))
acl_go_tot1 = np.array(list3)



list1 = []
list1 = acl_go1["message"].tolist()
list2 = []
for x in list1:
    if x.count("access control")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[5]))
acl_go_fun1 = np.array(list3)







#acl go 2 invoker incremental first arch
list1 = []
list1 = acl_go2["message"].tolist()
listMDB = []
for x in list1:
    if x.count("Read")>0:
        listMDB.append(x.split(" "))
listMDB2 = []
for x in listMDB:
    listMDB2.append(int(x[-2]))
acl_go_mdb2 = np.array(listMDB2)


list1 = []
list1 = acl_go2["message"].tolist()
list2 = []
for x in list1:
    if x.count("example")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    match = re.match(r"([\d.]+)([a-zA-Z]+)", x[-1])
    if match.group(2) == "s":
        list3.append(float(match.group(1))*1000)
    else:
        list3.append(float(match.group(1)))
acl_go_tot2 = np.array(list3)



list1 = []
list1 = acl_go2["message"].tolist()
list2 = []
for x in list1:
    if x.count("access control")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[5]))
acl_go_fun2 = np.array(list3)







#acl go 4 invoker incremental first arch
list1 = []
list1 = acl_go4["message"].tolist()
listMDB = []
for x in list1:
    if x.count("Read")>0:
        listMDB.append(x.split(" "))
listMDB2 = []
for x in listMDB:
    listMDB2.append(int(x[-2]))
acl_go_mdb4 = np.array(listMDB2)


list1 = []
list1 = acl_go4["message"].tolist()
list2 = []
for x in list1:
    if x.count("example")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    match = re.match(r"([\d.]+)([µa-zA-Z]+)", x[-1])
    if match.group(2) == "s":
        list3.append(float(match.group(1))*1000)
    elif match.group(2) == "µs":
        list3.append(float(match.group(1))/1000)
    else:
        list3.append(float(match.group(1)))
acl_go_tot4 = np.array(list3)



list1 = []
list1 = acl_go4["message"].tolist()
list2 = []
for x in list1:
    if x.count("access control")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[5]))
acl_go_fun4= np.array(list3)





acl_go_tot1_rps = []
acl_go_mdb1_rps = []
acl_go_fun1_rps = []
used = 0
for x in range (2, 501, 2):
    y = np.mean(acl_go_tot1[used:used+x])
    acl_go_tot1_rps.append(y)
    y = np.mean(acl_go_mdb1[used:used+x])
    acl_go_mdb1_rps.append(y)
    y = np.mean(acl_go_fun1[used:used+x])
    acl_go_fun1_rps.append(y)
    used = used+x


acl_go_tot2_rps = []
acl_go_mdb2_rps = []
acl_go_fun2_rps = []
used = 0
for x in range (2, 501, 2):
    y = np.mean(acl_go_tot2[used:used+x])
    acl_go_tot2_rps.append(y)
    y = np.mean(acl_go_mdb2[used:used+x])
    acl_go_mdb2_rps.append(y)
    y = np.mean(acl_go_fun2[used:used+x])
    acl_go_fun2_rps.append(y)
    used = used+x


acl_go_tot4_rps = []
acl_go_mdb4_rps = []
acl_go_fun4_rps = []
used = 0
for x in range (2, 501, 2):
    y = np.mean(acl_go_tot4[used:used+x])
    acl_go_tot4_rps.append(y)
    y = np.mean(acl_go_mdb4[used:used+x])
    acl_go_mdb4_rps.append(y)
    y = np.mean(acl_go_fun4[used:used+x])
    acl_go_fun4_rps.append(y)
    used = used+x


rps_go = range(2, 501, 2)
# Out:
# C:\Users\Fabio Gentili\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\Fabio Gentili\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
#acl go tot incremental first arch
fig, ax = plt.subplots(figsize = (20,8)) 
ax.set_title("Different configurations with incremental workload (Go function)", fontsize = 40)
ax.set_xlabel('Requests / sec', fontsize = 26)
ax.set_ylabel('Mean end-to-end latency [ms]', fontsize = 26)
ax.plot(rps_go, acl_go_tot1_rps, label = '1x invoker')
ax.plot(rps_go, acl_go_tot2_rps, label = '2x invoker')
ax.plot(rps_go, acl_go_tot4_rps, label = '4x invoker')
#ax.plot(log_go_tot, label = 'log function')
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
ax.grid(True, linewidth=0.5)
#~ax.set_xticks(range(5,21,5))
plt.yscale('log')
plt.legend(loc = 'upper left')
plt.rc('legend', fontsize = 25)
plt.show()

# %%
#acl go mdb incremental first arch
fig, ax = plt.subplots(figsize = (20,8)) 
ax.set_title("Different configurations with incremental workload (Go function)", fontsize = 40)
ax.set_xlabel('Requests / sec', fontsize = 26)
ax.set_ylabel('Mean service binding time [ms]', fontsize = 26)
ax.plot(rps_go, acl_go_mdb1_rps, label = '1x invoker')
ax.plot(rps_go, acl_go_mdb2_rps, label = '2x invoker')
ax.plot(rps_go, acl_go_mdb4_rps, label = '4x invoker')
#ax.plot(log_go_tot, label = 'log function')
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
ax.grid(True, linewidth=0.5)
#ax.set_xticks(range(5,21,5))
#~plt.yscale('log')
plt.legend(loc = 'upper right')
plt.rc('legend', fontsize = 25)
plt.show()

# %%
#acl go fun incremental first arch
fig, ax = plt.subplots(figsize = (20,8)) 
ax.set_title("Different configurations with incremental workload (Go function)", fontsize = 40)
ax.set_xlabel('Requests / sec', fontsize = 26)
ax.set_ylabel('Mean service invocation time [ms]', fontsize = 26)
ax.plot(rps_go, acl_go_fun1_rps, label = '1x invoker')
ax.plot(rps_go, acl_go_fun2_rps, label = '2x invoker')
ax.plot(rps_go, acl_go_fun4_rps, label = '4x invoker')
#ax.plot(log_go_tot, label = 'log function')
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
ax.grid(True, linewidth=0.5)
#ax.set_xticks(range(5,21,5))
plt.yscale('log')
plt.legend(loc = 'upper right')
plt.rc('legend', fontsize = 25)
plt.show()

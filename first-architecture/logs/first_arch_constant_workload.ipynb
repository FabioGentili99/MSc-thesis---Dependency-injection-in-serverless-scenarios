# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

logs_first_arch_java_1_invoker_constant1 = "logs_first_arch_java_1_invoker_constant110.txt"
logs_first_arch_java_2_invoker_constant1 = "logs_first_arch_java_2_invoker_constant110.txt"
logs_first_arch_java_4_invoker_constant1 = "logs_first_arch_java_4_invoker_constant110.txt"

logs_first_arch_java_4_invoker_constant2 = "logs_first_arch_java_4_invoker_constant111.txt"


acl_java1 = pd.read_csv (logs_first_arch_java_1_invoker_constant1, names = ["timestamp", "level", "message"])
acl_java2 = pd.read_csv (logs_first_arch_java_2_invoker_constant1, names = ["timestamp", "level", "message"])
acl_java4 = pd.read_csv (logs_first_arch_java_4_invoker_constant1, names = ["timestamp", "level", "message"])

acl_java42 = pd.read_csv (logs_first_arch_java_4_invoker_constant2, names = ["timestamp", "level", "message"])

acl_java4 = pd.concat([acl_java4, acl_java42])
acl_java4 = acl_java4.sort_values(by=['timestamp'])


#acl java 1 invoker constant first arch
list1 = []
list1 = acl_java1["message"].tolist()
listMDB = []
for x in list1:
    if x.count("Read")>0:
        listMDB.append(x.split(" "))
listMDB2 = []
for x in listMDB:
    listMDB2.append(int(x[-2]))
acl_java_mdb1 = np.array(listMDB2)

list1 = []
list1 = acl_java1["message"].tolist()
list2 = []
for x in list1:
    if x.count("example")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    match = re.match(r"([\d.]+)([a-zA-Z]+)", x[-1])
    if match.group(2) == "s":
        list3.append(float(match.group(1))*1000)
    else:
        list3.append(float(match.group(1)))
acl_java_tot1 = np.array(list3)

list1 = []
list1 = acl_java1["message"].tolist()
list2 = []
for x in list1:
    if x.count("access")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[-2]))
acl_java_fun1 = np.array(list3)



#acl java 2 invoker constant first arch
list1 = []
list1 = acl_java2["message"].tolist()
listMDB = []
for x in list1:
    if x.count("Read")>0:
        listMDB.append(x.split(" "))
listMDB2 = []
for x in listMDB:
    listMDB2.append(int(x[-2]))
acl_java_mdb2 = np.array(listMDB2)

list1 = []
list1 = acl_java2["message"].tolist()
list2 = []
for x in list1:
    if x.count("example")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    match = re.match(r"([\d.]+)([a-zA-Z]+)", x[-1])
    if match.group(2) == "s":
        list3.append(float(match.group(1))*1000)
    else:
        list3.append(float(match.group(1)))
acl_java_tot2 = np.array(list3)

list1 = []
list1 = acl_java2["message"].tolist()
list2 = []
for x in list1:
    if x.count("access")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[-2]))
acl_java_fun2 = np.array(list3)




#acl java 4 invoker constant first arch
list1 = []
list1 = acl_java4["message"].tolist()
listMDB = []
for x in list1:
    if x.count("Read")>0:
        listMDB.append(x.split(" "))
listMDB2 = []
for x in listMDB:
    listMDB2.append(int(x[-2]))
acl_java_mdb4 = np.array(listMDB2)

list1 = []
list1 = acl_java4["message"].tolist()
list2 = []
for x in list1:
    if x.count("example")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    match = re.match(r"([\d.]+)([a-zA-Z]+)", x[-1])
    if match.group(2) == "s":
        list3.append(float(match.group(1))*1000)
    else:
        list3.append(float(match.group(1)))
acl_java_tot4 = np.array(list3)

list1 = []
list1 = acl_java4["message"].tolist()
list2 = []
for x in list1:
    if x.count("access")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[-2]))
acl_java_fun4 = np.array(list3)




acl_java_tot1_mean = np.mean (acl_java_tot1)
acl_java_mdb1_mean = np.mean (acl_java_mdb1)
acl_java_fun1_mean = np.mean (acl_java_fun1)

acl_java_tot2_mean = np.mean (acl_java_tot2)
acl_java_mdb2_mean = np.mean (acl_java_mdb2)
acl_java_fun2_mean = np.mean (acl_java_fun2)

acl_java_tot4_mean = np.mean (acl_java_tot4)
acl_java_mdb4_mean = np.mean (acl_java_mdb4)
acl_java_fun4_mean = np.mean (acl_java_fun4)

print (acl_java_tot1_mean)
print (acl_java_tot2_mean)
print (acl_java_tot4_mean)

print (acl_java_mdb1_mean)
print (acl_java_mdb2_mean)
print (acl_java_mdb4_mean)

print (acl_java_fun1_mean)
print (acl_java_fun2_mean)
print (acl_java_fun4_mean)
# Out:
# 1306.8500666666666
# 8152.392201404166
# 7573.665042170834
# 46.95
# 120.14166666666667
# 120.39375
# 63.233333333333334
# 144.17916666666667
# 158.63333333333333

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

logs_first_arch_js_1_invoker_constant1 = "logs_first_arch_js_1_invoker_constant110.txt"
logs_first_arch_js_2_invoker_constant1 = "logs_first_arch_js_2_invoker_constant110.txt"
logs_first_arch_js_4_invoker_constant1 = "logs_first_arch_js_4_invoker_constant110.txt"

logs_first_arch_js_4_invoker_constant2 = "logs_first_arch_js_4_invoker_constant111.txt"



acl_js1 = pd.read_csv (logs_first_arch_js_1_invoker_constant1, names = ["timestamp", "level", "message"])
acl_js2 = pd.read_csv (logs_first_arch_js_2_invoker_constant1, names = ["timestamp", "level", "message"])
acl_js4 = pd.read_csv (logs_first_arch_js_4_invoker_constant1, names = ["timestamp", "level", "message"])

acl_js42 = pd.read_csv (logs_first_arch_js_4_invoker_constant2, names = ["timestamp", "level", "message"])


acl_js4 = pd.concat([acl_js4, acl_js42])
acl_js4 = acl_js4.sort_values(by=['timestamp'])




#acl js 1 invoker constant first arch
list1 = []
list1 = acl_js1["message"].tolist()
listMDB = []
for x in list1:
    if x.count("Read")>0:
        listMDB.append(x.split(" "))
listMDB2 = []
for x in listMDB:
    listMDB2.append(int(x[-3]))
acl_js_mdb1 = np.array(listMDB2)

list1 = []
list1 = acl_js1["message"].tolist()
list2 = []
for x in list1:
    if x.count("example")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    match = re.match(r"([\d.]+)([a-zA-Z]+)", x[-1])
    if match.group(2) == "s":
        list3.append(float(match.group(1))*1000)
    else:
        list3.append(float(match.group(1)))
acl_js_tot1 = np.array(list3)

list1 = []
list1 = acl_js1["message"].tolist()
list2 = []
for x in list1:
    if x.count("access")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[-3]))
acl_js_fun1 = np.array(list3)



#acl js 2 invoker constant first arch
list1 = []
list1 = acl_js2["message"].tolist()
listMDB = []
for x in list1:
    if x.count("Read")>0:
        listMDB.append(x.split(" "))
listMDB2 = []
for x in listMDB:
    listMDB2.append(int(x[-3]))
acl_js_mdb2 = np.array(listMDB2)

list1 = []
list1 = acl_js2["message"].tolist()
list2 = []
for x in list1:
    if x.count("example")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    match = re.match(r"([\d.]+)([a-zA-Z]+)", x[-1])
    if match.group(2) == "s":
        list3.append(float(match.group(1))*1000)
    else:
        list3.append(float(match.group(1)))
acl_js_tot2 = np.array(list3)

list1 = []
list1 = acl_js2["message"].tolist()
list2 = []
for x in list1:
    if x.count("access")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[-3]))
acl_js_fun2 = np.array(list3)




#acl js 4 invoker constant first arch
list1 = []
list1 = acl_js4["message"].tolist()
listMDB = []
for x in list1:
    if x.count("Read")>0:
        listMDB.append(x.split(" "))
listMDB2 = []
for x in listMDB:
    listMDB2.append(int(x[-3]))
acl_js_mdb4 = np.array(listMDB2)

list1 = []
list1 = acl_js4["message"].tolist()
list2 = []
for x in list1:
    if x.count("example")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    match = re.match(r"([\d.]+)([a-zA-Z]+)", x[-1])
    if match.group(2) == "s":
        list3.append(float(match.group(1))*1000)
    else:
        list3.append(float(match.group(1)))
acl_js_tot4 = np.array(list3)

list1 = []
list1 = acl_js4["message"].tolist()
list2 = []
for x in list1:
    if x.count("access")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[-3]))
acl_js_fun4 = np.array(list3)




acl_js_tot1_mean = np.mean (acl_js_tot1)
acl_js_mdb1_mean = np.mean (acl_js_mdb1)
acl_js_fun1_mean = np.mean (acl_js_fun1)

acl_js_tot2_mean = np.mean (acl_js_tot2)
acl_js_mdb2_mean = np.mean (acl_js_mdb2)
acl_js_fun2_mean = np.mean (acl_js_fun2)

acl_js_tot4_mean = np.mean (acl_js_tot4)
acl_js_mdb4_mean = np.mean (acl_js_mdb4)
acl_js_fun4_mean = np.mean (acl_js_fun4)

print (acl_js_tot1_mean)
print (acl_js_tot2_mean)
print (acl_js_tot4_mean)

print (acl_js_mdb1_mean)
print (acl_js_mdb2_mean)
print (acl_js_mdb4_mean)

print (acl_js_fun1_mean)
print (acl_js_fun2_mean)
print (acl_js_fun4_mean)
# Out:
# 257.09617815
# 296.16225950625
# 399.764744578125
# 18.525
# 19.066666666666666
# 20.119791666666668
# 31.6625
# 32.90416666666667
# 48.34791666666667

# %%
logs_first_arch_go_1_invoker_constant1 = "logs_first_arch_go_1_invoker_constant110.txt"
logs_first_arch_go_2_invoker_constant1 = "logs_first_arch_go_2_invoker_constant110.txt"
logs_first_arch_go_4_invoker_constant1 = "logs_first_arch_go_4_invoker_constant110.txt"

logs_first_arch_go_4_invoker_constant2 = "logs_first_arch_go_4_invoker_constant111.txt"



acl_go1 = pd.read_csv (logs_first_arch_go_1_invoker_constant1, names = ["timestamp", "level", "message"])
acl_go2 = pd.read_csv (logs_first_arch_go_2_invoker_constant1, names = ["timestamp", "level", "message"])
acl_go4 = pd.read_csv (logs_first_arch_go_4_invoker_constant1, names = ["timestamp", "level", "message"])

acl_go42 = pd.read_csv (logs_first_arch_go_4_invoker_constant2, names = ["timestamp", "level", "message"])

acl_go4 = pd.concat([acl_go4, acl_go42])
acl_go4 = acl_go4.sort_values(by=['timestamp'])



#acl go 1 invoker constant first arch
list1 = []
list1 = acl_go1["message"].tolist()
listMDB = []
for x in list1:
    if x.count("Read")>0:
        listMDB.append(x.split(" "))
listMDB2 = []
for x in listMDB:
    listMDB2.append(int(x[-2]))
acl_go_mdb1 = np.array(listMDB2)


list1 = []
list1 = acl_go1["message"].tolist()
list2 = []
for x in list1:
    if x.count("example")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    match = re.match(r"([\d.]+)([a-zA-Z]+)", x[-1])
    if match.group(2) == "s":
        list3.append(float(match.group(1))*1000)
    else:
        list3.append(float(match.group(1)))
acl_go_tot1 = np.array(list3)



list1 = []
list1 = acl_go1["message"].tolist()
list2 = []
for x in list1:
    if x.count("access control")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[5]))
acl_go_fun1 = np.array(list3)



#acl go 2 invoker constant first arch
list1 = []
list1 = acl_go2["message"].tolist()
listMDB = []
for x in list1:
    if x.count("Read")>0:
        listMDB.append(x.split(" "))
listMDB2 = []
for x in listMDB:
    listMDB2.append(int(x[-2]))
acl_go_mdb2 = np.array(listMDB2)


list1 = []
list1 = acl_go2["message"].tolist()
list2 = []
for x in list1:
    if x.count("example")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    match = re.match(r"([\d.]+)([a-zA-Z]+)", x[-1])
    if match.group(2) == "s":
        list3.append(float(match.group(1))*1000)
    else:
        list3.append(float(match.group(1)))
acl_go_tot2 = np.array(list3)



list1 = []
list1 = acl_go2["message"].tolist()
list2 = []
for x in list1:
    if x.count("access control")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[5]))
acl_go_fun2 = np.array(list3)



#acl go 4 invoker constant first arch
list1 = []
list1 = acl_go4["message"].tolist()
listMDB = []
for x in list1:
    if x.count("Read")>0:
        listMDB.append(x.split(" "))
listMDB2 = []
for x in listMDB:
    listMDB2.append(int(x[-2]))
acl_go_mdb4 = np.array(listMDB2)


list1 = []
list1 = acl_go4["message"].tolist()
list2 = []
for x in list1:
    if x.count("example")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    match = re.match(r"([\d.]+)([a-zA-Z]+)", x[-1])
    if match.group(2) == "s":
        list3.append(float(match.group(1))*1000)
    else:
        list3.append(float(match.group(1)))
acl_go_tot4 = np.array(list3)



list1 = []
list1 = acl_go4["message"].tolist()
list2 = []
for x in list1:
    if x.count("access control")>0:
        list2.append(x.split(" "))
list3 = []
for x in list2:
    list3.append(int(x[5]))
acl_go_fun4 = np.array(list3)



acl_go_tot1_mean = np.mean (acl_go_tot1)
acl_go_mdb1_mean = np.mean (acl_go_mdb1)
acl_go_fun1_mean = np.mean (acl_go_fun1)

acl_go_tot2_mean = np.mean (acl_go_tot2)
acl_go_mdb2_mean = np.mean (acl_go_mdb2)
acl_go_fun2_mean = np.mean (acl_go_fun2)

acl_go_tot4_mean = np.mean (acl_go_tot4)
acl_go_mdb4_mean = np.mean (acl_go_mdb4)
acl_go_fun4_mean = np.mean (acl_go_fun4)

print (acl_go_tot1_mean)
print (acl_go_tot2_mean)
print (acl_go_tot4_mean)

print (acl_go_mdb1_mean)
print (acl_go_mdb2_mean)
print (acl_go_mdb4_mean)

print (acl_go_fun1_mean)
print (acl_go_fun2_mean)
print (acl_go_fun4_mean)
# Out:
# 170.27353976266667
# 242.61252757233333
# 293.454672593625
# 2.120833333333333
# 6.406083333333333
# 6.190958333333334
# 7.116666666666666
# 6.772833333333334
# 11.659208333333334

# %%
js_tot = [acl_js_tot1_mean, acl_js_tot2_mean, acl_js_tot4_mean] 
js_mdb = [acl_js_mdb1_mean, acl_js_mdb2_mean, acl_js_mdb4_mean] 
js_fun = [acl_js_fun1_mean, acl_js_fun2_mean, acl_js_fun4_mean] 

java_tot = [acl_java_tot1_mean, acl_java_tot2_mean, acl_java_tot4_mean] 
java_mdb = [acl_java_mdb1_mean, acl_java_mdb2_mean, acl_java_mdb4_mean] 
java_fun = [acl_java_fun1_mean, acl_java_fun2_mean, acl_java_fun4_mean] 

go_tot = [acl_go_tot1_mean, acl_go_tot2_mean, acl_go_tot4_mean] 
go_mdb = [acl_go_mdb1_mean, acl_go_mdb2_mean, acl_go_mdb4_mean] 
go_fun = [acl_go_fun1_mean, acl_go_fun2_mean, acl_go_fun4_mean] 


barWidth = 0.30
fig = plt.subplots(figsize =(12, 8)) 
br1 = np.arange(len(js_tot)) 
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2] 

plt.bar(br1, js_mdb, color ='r', width = barWidth, 
        edgecolor ='grey', label ='service binding time') 
plt.bar(br2, js_fun, color ='g', width = barWidth, 
        edgecolor ='grey', label ='service invocation time') 
plt.bar(br3, js_tot, color ='b', width = barWidth, 
        edgecolor ='grey', label ='end-to-end latency') 
plt.xlabel('Different configurations (Javascript function)', fontweight ='bold', fontsize = 24) 
plt.ylabel('mean duration (ms)', fontweight ='bold', fontsize = 24) 
plt.xticks([r + barWidth for r in range(len(js_tot))], 
        ['1x invoker - 4 req/s', '2x invokers - 8 req/s', '4x invokers - 16 req/s'], fontsize = 18)

plt.legend(fontsize = 16)
plt.show()

# %%
barWidth = 0.30
fig = plt.subplots(figsize =(12, 8)) 
br1 = np.arange(len(js_tot)) 
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2] 

plt.bar(br1, java_mdb, color ='r', width = barWidth, 
        edgecolor ='grey', label ='service binding time') 
plt.bar(br2, java_fun, color ='g', width = barWidth, 
        edgecolor ='grey', label ='service invocation time') 
plt.bar(br3, java_tot, color ='b', width = barWidth, 
        edgecolor ='grey', label ='end-to-end latency') 
plt.xlabel('Different configurations (Java function)', fontweight ='bold', fontsize = 24) 
plt.ylabel('mean duration (ms)', fontweight ='bold', fontsize = 24) 
plt.xticks([r + barWidth for r in range(len(js_tot))], 
        ['1x invoker - 2 req/s', '2x invokers - 4 req/s', '4x invokers - 8 req/s'], fontsize = 18)

plt.legend(fontsize = 16)
plt.show()

# %%
barWidth = 0.30
fig = plt.subplots(figsize =(12, 8)) 
br1 = np.arange(len(js_tot)) 
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2] 

plt.bar(br1, go_mdb, color ='r', width = barWidth, 
        edgecolor ='grey', label ='service binding time') 
plt.bar(br2, go_fun, color ='g', width = barWidth, 
        edgecolor ='grey', label ='service invocation time') 
plt.bar(br3, go_tot, color ='b', width = barWidth, 
        edgecolor ='grey', label ='end-to-end latency') 
plt.xlabel('Different configurations (Go function)', fontweight ='bold', fontsize = 24) 
plt.ylabel('mean duration (ms)', fontweight ='bold', fontsize = 24) 
plt.xticks([r + barWidth for r in range(len(js_tot))], 
        ['1x invoker - 100 req/s', '2x invokers - 200 req/s', '4x invokers - 400 req/s'], fontsize = 18)

plt.legend(fontsize = 16)
plt.show()
